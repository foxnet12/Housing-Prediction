# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error

# %% [markdown]
# ## Gives files to test.

# %%
df1 = pd.read_csv('train.csv')
df2 = pd.read_csv('test.csv')

# %% [markdown]
# ## Combine files

# %%
df = pd.concat([df1, df2], axis=0)

# %% [markdown]
# ##  Filling missing values

# %%
df.fillna(value='NaN', inplace=True)

# %% [markdown]
# ## Split the combined files

# %%
df1 = df[:len(df1)]
df2 = df[len(df2):]

# %%
df1
# Out:
#         Id  MSSubClass MSZoning LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL        65.0     8450   Pave   NaN      Reg
# 1        2          20       RL        80.0     9600   Pave   NaN      Reg
# 2        3          60       RL        68.0    11250   Pave   NaN      IR1
# 3        4          70       RL        60.0     9550   Pave   NaN      IR1
# 4        5          60       RL        84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...         ...      ...    ...   ...      ...
# 1455  1456          60       RL        62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL        85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL        66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL        68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL        75.0     9937   Pave   NaN      Reg
#
# ...

# %% [markdown]
# ## Encode categorical variables

# %%
df1 = pd.get_dummies(df1)
df2 = pd.get_dummies(df2)

# %%
df1, df2= df1.align(df2, join='inner', axis=1)

# %%
df1
# Out:
#         Id  MSSubClass  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0        1          60     8450            7            5       2003
# 1        2          20     9600            6            8       1976
# 2        3          60    11250            7            5       2001
# 3        4          70     9550            7            5       1915
# 4        5          60    14260            8            5       2000
# ...    ...         ...      ...          ...          ...        ...
# 1455  1456          60     7917            6            5       1999
# 1456  1457          20    13175            6            6       1978
# 1457  1458          70     9042            7            9       1941
# 1458  1459          20     9717            5            6       1950
# 1459  1460          20     9937            5            6       1965
#
#       YearRemodAdd  1stFlrSF  2ndFlrSF  LowQualFinSF  ...  SaleType_New  \
# ...

# %% [markdown]
# ## Split the df1_encoded into features and target variable

# %%
print(df1.columns)
# Out:
# Index(['Id', 'MSSubClass', 'LotArea', 'OverallQual', 'OverallCond',
#        'YearBuilt', 'YearRemodAdd', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        ...
#        'SaleType_New', 'SaleType_Oth', 'SaleType_WD', 'SaleCondition_Abnorml',
#        'SaleCondition_AdjLand', 'SaleCondition_Alloca', 'SaleCondition_Family',
#        'SaleCondition_Normal', 'SaleCondition_Partial', 'SalePrice_147500.0'],
#       dtype='object', length=2149)

# %%
y = df1['SalePrice_147500.0']

# %%
x = df1.drop('SalePrice_147500.0', axis=1)

# %% [markdown]
# ## Split the df1_encoded into features and target variable

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %% [markdown]
# ## Model Random Forest Regressor

# %%
encode_df1=pd.get_dummies(df1)

# %%
model = RandomForestRegressor(random_state=42)

# %%
model.fit(x_train, y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %%
y_pred = model.predict(x)

# %% [markdown]
# ## Mean absolute error

# %%
    mae = mean_absolute_error(y, y_pred)
    print('Mean Absolute Error:', mae)
